# %% [markdown]
# <a href="https://colab.research.google.com/github/MinervaNunez/Proyecto-de-Python-BEDU/blob/Rama-Jesus/Proyecto_final_E8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Proyecto de Python Equipo 8**
#
#
# ¿Cuál es el registro de personas extraviadas o desaparecidas en México durante el periodo comprendido de 1968 – 2018?

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('https://raw.githubusercontent.com/MinervaNunez/Proyecto-de-Python-BEDU/Rama-Jesus/RNPEDFC.csv', sep=',', encoding='ISO-8859-1')
df
# Out:
#       Fecha en que se le vio por ultima vez  \
# 0                                2012-03-18
# 1                                2007-02-05
# 2                                2009-03-14
# 3                                2006-12-23
# 4                                2008-01-11
# ...                                     ...
# 36260                            2018-04-26
# 36261                            2018-01-08
# 36262                            2015-02-02
# 36263                            2017-08-22
# 36264                            2018-04-11
#
#       Hora en que se le vio por ultima vez  \
# 0                                 05:00:00
# 1                                 02:00:26
# 2                                 08:30:54
# 3                                 08:00:28
# 4                                 12:00:17
# ...                                    ...
# 36260                             08:00:00
# 36261                             11:00:00
# 36262                             07:00:00
# 36263                             04:00:00
# 36264                             02:00:00
#
#       Pais en que se le vio por ultima vez  \
# 0                                   MEXICO
# 1                                   MEXICO
# 2                                   MEXICO
# 3                                   MEXICO
# 4                                   MEXICO
# ...                                    ...
# 36260                               MEXICO
# 36261                               MEXICO
# 36262                               MEXICO
# 36263                               MEXICO
# 36264                               MEXICO
#
#       Entidad en que se le vio por ultima vez  \
# 0                                      SONORA
# 1                            ESTADO DE MEXICO
# 2                            ESTADO DE MEXICO
# 3                            ESTADO DE MEXICO
# 4                            ESTADO DE MEXICO
# ...                                       ...
# 36260                                  PUEBLA
# 36261                                  COLIMA
# 36262                                  PUEBLA
# 36263                                  COLIMA
# 36264                              NUEVO LEON
#
#       Municipio en que se le vio por ultima vez  \
# 0                                       NAVOJOA
# 1                                VALLE DE BRAVO
# 2                                        CHALCO
# 3                           TLALNEPANTLA DE BAZ
# 4                                        TOLUCA
# ...                                         ...
# 36260                                    PUEBLA
# 36261                          VILLA DE ALVAREZ
# 36262                                     CHILA
# 36263                          VILLA DE ALVAREZ
# 36264                  SAN NICOLAS DE LOS GARZA
#
#       Localidad en que se le vio por ultima vez Nacionalidad Estatura  \
# 0                                       NAVOJOA     MEXICANA      1.1
# 1                                VALLE DE BRAVO     MEXICANA      1.1
# 2                                        CHALCO     MEXICANA      1.1
# 3                           TLALNEPANTLA DE BAZ     MEXICANA      1.1
# 4                                        TOLUCA     MEXICANA      1.1
# ...                                         ...          ...      ...
# 36260                                    PUEBLA     MEXICANA      1.6
# 36261                          VILLA DE ALVAREZ     MEXICANA      1.7
# 36262                      CHILAS DE LAS FLORES     MEXICANA     1.77
# 36263                          VILLA DE ALVAREZ     MEXICANA     1.76
# 36264                  SAN NICOLAS DE LOS GARZA     MEXICANA      1.6
#
#       Complexion    Sexo Edad  \
# 0        DELGADA   MUJER    7
# 1        DELGADA   MUJER    4
# 2        DELGADA  HOMBRE    6
# 3        DELGADA  HOMBRE   10
# 4        DELGADA  HOMBRE    4
# ...          ...     ...  ...
# 36260    DELGADA  HOMBRE   22
# 36261    ROBUSTA   MUJER   27
# 36262    MEDIANA   MUJER   86
# 36263    ROBUSTA  HOMBRE   41
# 36264    DELGADA   MUJER   14
#
#                        Descripcion de senas particulares            Etnia  \
# 0      TIENE UNA CICATRIZ EN LA RODILLA IZQUIERDA POR...  NO ESPECIFICADO
# 1                                        NO ESPECIFICADO  NO ESPECIFICADO
# 2      MANCHAS, PARTE SUPERIOR DE PIERNA DERECHA, CIC...  NO ESPECIFICADO
# 3      LUNARES, A LA ALTURA DE LA CINTURAFORMA DE MAN...  NO ESPECIFICADO
# 4                                        NO ESPECIFICADO  NO ESPECIFICADO
# ...                                                  ...              ...
# 36260  LUNAR EN LA MEJILLA Y TATUAJE EN EL CUELLO EN ...  NO ESPECIFICADO
# 36261  EL OJO IZQUIERDO TIENE UN ENFERMEDAD COMO TIC,...  NO ESPECIFICADO
# 36262                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36263  TATUAJE EN EL BRAZO IZQUIERDO CON LA IMAGEN DE...  NO ESPECIFICADO
# 36264                                    NO ESPECIFICADO  NO ESPECIFICADO
#
#       Discapacidad Dependencia que envio la informacion
# 0          NINGUNO                         FGE - SONORA
# 1          NINGUNO               FGJ - ESTADO DE MEXICO
# 2          NINGUNO               FGJ - ESTADO DE MEXICO
# 3          NINGUNO               FGJ - ESTADO DE MEXICO
# 4          NINGUNO               FGJ - ESTADO DE MEXICO
# ...            ...                                  ...
# 36260      NINGUNO                         FGE - PUEBLA
# 36261      NINGUNO                         PGJ - COLIMA
# 36262      NINGUNO                         FGE - PUEBLA
# 36263      NINGUNO                         PGJ - COLIMA
# 36264      NINGUNO                     PGJ - NUEVO LEON
#
# [36265 rows x 15 columns]

# %%
#Conocemos el dataset Original
df.shape
# Out:
# (36265, 15)

# %%
#Conocemos el dataset Original, los tipos de datos
df.dtypes
# Out:
# Fecha en que se le vio por ultima vez        object
# Hora en que se le vio por ultima vez         object
# Pais en que se le vio por ultima vez         object
# Entidad en que se le vio por ultima vez      object
# Municipio en que se le vio por ultima vez    object
# Localidad en que se le vio por ultima vez    object
# Nacionalidad                                 object
# Estatura                                     object
# Complexion                                   object
# Sexo                                         object
# Edad                                         object
# Descripcion de senas particulares            object
# Etnia                                        object
# Discapacidad                                 object
# Dependencia que envio la informacion         object
# dtype: object

# %%
#Exploramos NAN
df.isna().sum()
# Out:
# Fecha en que se le vio por ultima vez        0
# Hora en que se le vio por ultima vez         0
# Pais en que se le vio por ultima vez         0
# Entidad en que se le vio por ultima vez      0
# Municipio en que se le vio por ultima vez    0
# Localidad en que se le vio por ultima vez    0
# Nacionalidad                                 0
# Estatura                                     0
# Complexion                                   0
# Sexo                                         0
# Edad                                         0
# Descripcion de senas particulares            0
# Etnia                                        0
# Discapacidad                                 0
# Dependencia que envio la informacion         0
# dtype: int64

# %%
# Reindexamos el data set para que se vea coherente 
fin=len(df.index)
fin
# Out:
# 36265

# %%
lst = list(np.arange(1,fin+1))
#lst
len(lst)
# Out:
# 36265

# %%
df=df.reindex(lst, method='ffill')
df
# Out:
#       Fecha en que se le vio por ultima vez  \
# 1                                2007-02-05
# 2                                2009-03-14
# 3                                2006-12-23
# 4                                2008-01-11
# 5                                2012-05-27
# ...                                     ...
# 36261                            2018-01-08
# 36262                            2015-02-02
# 36263                            2017-08-22
# 36264                            2018-04-11
# 36265                            2018-04-11
#
#       Hora en que se le vio por ultima vez  \
# 1                                 02:00:26
# 2                                 08:30:54
# 3                                 08:00:28
# 4                                 12:00:17
# 5                                 12:00:43
# ...                                    ...
# 36261                             11:00:00
# 36262                             07:00:00
# 36263                             04:00:00
# 36264                             02:00:00
# 36265                             02:00:00
#
#       Pais en que se le vio por ultima vez  \
# 1                                   MEXICO
# 2                                   MEXICO
# 3                                   MEXICO
# 4                                   MEXICO
# 5                                   MEXICO
# ...                                    ...
# 36261                               MEXICO
# 36262                               MEXICO
# 36263                               MEXICO
# 36264                               MEXICO
# 36265                               MEXICO
#
#       Entidad en que se le vio por ultima vez  \
# 1                            ESTADO DE MEXICO
# 2                            ESTADO DE MEXICO
# 3                            ESTADO DE MEXICO
# 4                            ESTADO DE MEXICO
# 5                            ESTADO DE MEXICO
# ...                                       ...
# 36261                                  COLIMA
# 36262                                  PUEBLA
# 36263                                  COLIMA
# 36264                              NUEVO LEON
# 36265                              NUEVO LEON
#
#       Municipio en que se le vio por ultima vez  \
# 1                                VALLE DE BRAVO
# 2                                        CHALCO
# 3                           TLALNEPANTLA DE BAZ
# 4                                        TOLUCA
# 5                                NICOLAS ROMERO
# ...                                         ...
# 36261                          VILLA DE ALVAREZ
# 36262                                     CHILA
# 36263                          VILLA DE ALVAREZ
# 36264                  SAN NICOLAS DE LOS GARZA
# 36265                  SAN NICOLAS DE LOS GARZA
#
#       Localidad en que se le vio por ultima vez Nacionalidad Estatura  \
# 1                                VALLE DE BRAVO     MEXICANA      1.1
# 2                                        CHALCO     MEXICANA      1.1
# 3                           TLALNEPANTLA DE BAZ     MEXICANA      1.1
# 4                                        TOLUCA     MEXICANA      1.1
# 5                                NICOLAS ROMERO     MEXICANA      1.1
# ...                                         ...          ...      ...
# 36261                          VILLA DE ALVAREZ     MEXICANA      1.7
# 36262                      CHILAS DE LAS FLORES     MEXICANA     1.77
# 36263                          VILLA DE ALVAREZ     MEXICANA     1.76
# 36264                  SAN NICOLAS DE LOS GARZA     MEXICANA      1.6
# 36265                  SAN NICOLAS DE LOS GARZA     MEXICANA      1.6
#
#       Complexion    Sexo Edad  \
# 1        DELGADA   MUJER    4
# 2        DELGADA  HOMBRE    6
# 3        DELGADA  HOMBRE   10
# 4        DELGADA  HOMBRE    4
# 5        DELGADA  HOMBRE    9
# ...          ...     ...  ...
# 36261    ROBUSTA   MUJER   27
# 36262    MEDIANA   MUJER   86
# 36263    ROBUSTA  HOMBRE   41
# 36264    DELGADA   MUJER   14
# 36265    DELGADA   MUJER   14
#
#                        Descripcion de senas particulares            Etnia  \
# 1                                        NO ESPECIFICADO  NO ESPECIFICADO
# 2      MANCHAS, PARTE SUPERIOR DE PIERNA DERECHA, CIC...  NO ESPECIFICADO
# 3      LUNARES, A LA ALTURA DE LA CINTURAFORMA DE MAN...  NO ESPECIFICADO
# 4                                        NO ESPECIFICADO  NO ESPECIFICADO
# 5                                        NO ESPECIFICADO  NO ESPECIFICADO
# ...                                                  ...              ...
# 36261  EL OJO IZQUIERDO TIENE UN ENFERMEDAD COMO TIC,...  NO ESPECIFICADO
# 36262                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36263  TATUAJE EN EL BRAZO IZQUIERDO CON LA IMAGEN DE...  NO ESPECIFICADO
# 36264                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36265                                    NO ESPECIFICADO  NO ESPECIFICADO
#
#       Discapacidad Dependencia que envio la informacion
# 1          NINGUNO               FGJ - ESTADO DE MEXICO
# 2          NINGUNO               FGJ - ESTADO DE MEXICO
# 3          NINGUNO               FGJ - ESTADO DE MEXICO
# 4          NINGUNO               FGJ - ESTADO DE MEXICO
# 5          NINGUNO               FGJ - ESTADO DE MEXICO
# ...            ...                                  ...
# 36261      NINGUNO                         PGJ - COLIMA
# 36262      NINGUNO                         FGE - PUEBLA
# 36263      NINGUNO                         PGJ - COLIMA
# 36264      NINGUNO                     PGJ - NUEVO LEON
# 36265      NINGUNO                     PGJ - NUEVO LEON
#
# [36265 rows x 15 columns]

# %%
# Se renombran las columnas y se colocan de manera estandar
column_name_mapping = {
    'Fecha en que se le vio por ultima vez': 'fecha_ultvz',
    'Hora en que se le vio por ultima vez': 'hora_ultvz',
    'Pais en que se le vio por ultima vez': 'pais_ultvz',
    'Entidad en que se le vio por ultima vez': 'entidad_ultvz',
    'Municipio en que se le vio por ultima vez': 'municipio_ultvz',
    'Localidad en que se le vio por ultima vez': 'localidad_ultvz',
    'Nacionalidad': 'nacionalidad',
    'Estatura': 'estatura',
    'Complexion': 'complexion',
    'Sexo': 'sexo',
    'Edad': 'edad',
    'Descripcion de senas particulares': 'senas_particulares',
    'Etnia': 'etnia',
    'Discapacidad': 'discapacidad',
    'Dependencia que envio la informacion': 'dependecia_origen'
    
}

# %%
# los cambios se aplican a una copia del dataset original 
df_2 = df.rename(columns=column_name_mapping)
df_2
# Out:
#       fecha_ultvz hora_ultvz pais_ultvz     entidad_ultvz  \
# 1      2007-02-05   02:00:26     MEXICO  ESTADO DE MEXICO
# 2      2009-03-14   08:30:54     MEXICO  ESTADO DE MEXICO
# 3      2006-12-23   08:00:28     MEXICO  ESTADO DE MEXICO
# 4      2008-01-11   12:00:17     MEXICO  ESTADO DE MEXICO
# 5      2012-05-27   12:00:43     MEXICO  ESTADO DE MEXICO
# ...           ...        ...        ...               ...
# 36261  2018-01-08   11:00:00     MEXICO            COLIMA
# 36262  2015-02-02   07:00:00     MEXICO            PUEBLA
# 36263  2017-08-22   04:00:00     MEXICO            COLIMA
# 36264  2018-04-11   02:00:00     MEXICO        NUEVO LEON
# 36265  2018-04-11   02:00:00     MEXICO        NUEVO LEON
#
#                 municipio_ultvz           localidad_ultvz nacionalidad  \
# 1                VALLE DE BRAVO            VALLE DE BRAVO     MEXICANA
# 2                        CHALCO                    CHALCO     MEXICANA
# 3           TLALNEPANTLA DE BAZ       TLALNEPANTLA DE BAZ     MEXICANA
# 4                        TOLUCA                    TOLUCA     MEXICANA
# 5                NICOLAS ROMERO            NICOLAS ROMERO     MEXICANA
# ...                         ...                       ...          ...
# 36261          VILLA DE ALVAREZ          VILLA DE ALVAREZ     MEXICANA
# 36262                     CHILA      CHILAS DE LAS FLORES     MEXICANA
# 36263          VILLA DE ALVAREZ          VILLA DE ALVAREZ     MEXICANA
# 36264  SAN NICOLAS DE LOS GARZA  SAN NICOLAS DE LOS GARZA     MEXICANA
# 36265  SAN NICOLAS DE LOS GARZA  SAN NICOLAS DE LOS GARZA     MEXICANA
#
#       estatura complexion    sexo edad  \
# 1          1.1    DELGADA   MUJER    4
# 2          1.1    DELGADA  HOMBRE    6
# 3          1.1    DELGADA  HOMBRE   10
# 4          1.1    DELGADA  HOMBRE    4
# 5          1.1    DELGADA  HOMBRE    9
# ...        ...        ...     ...  ...
# 36261      1.7    ROBUSTA   MUJER   27
# 36262     1.77    MEDIANA   MUJER   86
# 36263     1.76    ROBUSTA  HOMBRE   41
# 36264      1.6    DELGADA   MUJER   14
# 36265      1.6    DELGADA   MUJER   14
#
#                                       senas_particulares            etnia  \
# 1                                        NO ESPECIFICADO  NO ESPECIFICADO
# 2      MANCHAS, PARTE SUPERIOR DE PIERNA DERECHA, CIC...  NO ESPECIFICADO
# 3      LUNARES, A LA ALTURA DE LA CINTURAFORMA DE MAN...  NO ESPECIFICADO
# 4                                        NO ESPECIFICADO  NO ESPECIFICADO
# 5                                        NO ESPECIFICADO  NO ESPECIFICADO
# ...                                                  ...              ...
# 36261  EL OJO IZQUIERDO TIENE UN ENFERMEDAD COMO TIC,...  NO ESPECIFICADO
# 36262                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36263  TATUAJE EN EL BRAZO IZQUIERDO CON LA IMAGEN DE...  NO ESPECIFICADO
# 36264                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36265                                    NO ESPECIFICADO  NO ESPECIFICADO
#
#       discapacidad       dependecia_origen
# 1          NINGUNO  FGJ - ESTADO DE MEXICO
# 2          NINGUNO  FGJ - ESTADO DE MEXICO
# 3          NINGUNO  FGJ - ESTADO DE MEXICO
# 4          NINGUNO  FGJ - ESTADO DE MEXICO
# 5          NINGUNO  FGJ - ESTADO DE MEXICO
# ...            ...                     ...
# 36261      NINGUNO            PGJ - COLIMA
# 36262      NINGUNO            FGE - PUEBLA
# 36263      NINGUNO            PGJ - COLIMA
# 36264      NINGUNO        PGJ - NUEVO LEON
# 36265      NINGUNO        PGJ - NUEVO LEON
#
# [36265 rows x 15 columns]

# %%
# verificamos nuevamente los tipos de datos del nuevo dataframe
df_2.dtypes
# Out:
# fecha_ultvz           object
# hora_ultvz            object
# pais_ultvz            object
# entidad_ultvz         object
# municipio_ultvz       object
# localidad_ultvz       object
# nacionalidad          object
# estatura              object
# complexion            object
# sexo                  object
# edad                  object
# senas_particulares    object
# etnia                 object
# discapacidad          object
# dependecia_origen     object
# dtype: object

# %%
# Explorando el data set vemos que no tenemos NANS pero tenemos valores denominados "NO ESPECIFICADOS"
print(f'{("Columna"):42} =NO ESPECIFICADO= \n')
for col in df_2.columns:
    print(f'{(col):42} | {(df_2[col] == "NO ESPECIFICADO").sum()}')
# Out:
# Columna                                    =NO ESPECIFICADO=
#
# fecha_ultvz                                | 338
# hora_ultvz                                 | 16
# pais_ultvz                                 | 0
# entidad_ultvz                              | 29
# municipio_ultvz                            | 668
# localidad_ultvz                            | 3413
# nacionalidad                               | 2040
# estatura                                   | 11007
# complexion                                 | 10569
# sexo                                       | 0
# edad                                       | 3156
# senas_particulares                         | 18915
# etnia                                      | 36133
# discapacidad                               | 1047
# dependecia_origen                          | 0

# %%
# INICIAMOS CON LA LIMPIEZA DE DATOS
#
# Quitamos los no especificados del campo fecha, colocando en su lugar otra cadena =0000-00-00
df_2.loc[df_2['fecha_ultvz'] == 'NO ESPECIFICADO', 'fecha_ultvz'] = '0000-00-00'
#Revisamos de nuevo 
print(f'{("Columna"):42} =NO ESPECIFICADO= \n')
for col in df_2.columns:
    print(f'{(col):42} | {(df_2[col] == "NO ESPECIFICADO").sum()}')
# Out:
# Columna                                    =NO ESPECIFICADO=
#
# fecha_ultvz                                | 0
# hora_ultvz                                 | 16
# pais_ultvz                                 | 0
# entidad_ultvz                              | 29
# municipio_ultvz                            | 668
# localidad_ultvz                            | 3413
# nacionalidad                               | 2040
# estatura                                   | 11007
# complexion                                 | 10569
# sexo                                       | 0
# edad                                       | 3156
# senas_particulares                         | 18915
# etnia                                      | 36133
# discapacidad                               | 1047
# dependecia_origen                          | 0

# %%
#Convertimos el tipo de dato de fecha_ultvz especificando que si hay un error que continue
df_2['fecha_ultvz']= pd.to_datetime(df_2['fecha_ultvz'],errors='coerce')

#Convertimos la serie de edad a numerico con pd.to_numeric, inidicando que si encuentra error que continue, pero los pone como NAN
df_2['edad']= pd.to_numeric(df_2['edad'],errors='coerce')

#rellenamos los NAN de Edad con ceros
df_2["edad"]=df_2["edad"].fillna(0)
#Ahora si convertimos la columna edad a int
df_2["edad"]= df_2["edad"].astype(int)
df_2.dtypes
# Out:
# fecha_ultvz           datetime64[ns]
# hora_ultvz                    object
# pais_ultvz                    object
# entidad_ultvz                 object
# municipio_ultvz               object
# localidad_ultvz               object
# nacionalidad                  object
# estatura                      object
# complexion                    object
# sexo                          object
# edad                           int64
# senas_particulares            object
# etnia                         object
# discapacidad                  object
# dependecia_origen             object
# dtype: object

# %%
df_2
# Out:
#       fecha_ultvz hora_ultvz pais_ultvz     entidad_ultvz  \
# 1      2007-02-05   02:00:26     MEXICO  ESTADO DE MEXICO
# 2      2009-03-14   08:30:54     MEXICO  ESTADO DE MEXICO
# 3      2006-12-23   08:00:28     MEXICO  ESTADO DE MEXICO
# 4      2008-01-11   12:00:17     MEXICO  ESTADO DE MEXICO
# 5      2012-05-27   12:00:43     MEXICO  ESTADO DE MEXICO
# ...           ...        ...        ...               ...
# 36261  2018-01-08   11:00:00     MEXICO            COLIMA
# 36262  2015-02-02   07:00:00     MEXICO            PUEBLA
# 36263  2017-08-22   04:00:00     MEXICO            COLIMA
# 36264  2018-04-11   02:00:00     MEXICO        NUEVO LEON
# 36265  2018-04-11   02:00:00     MEXICO        NUEVO LEON
#
#                 municipio_ultvz           localidad_ultvz nacionalidad  \
# 1                VALLE DE BRAVO            VALLE DE BRAVO     MEXICANA
# 2                        CHALCO                    CHALCO     MEXICANA
# 3           TLALNEPANTLA DE BAZ       TLALNEPANTLA DE BAZ     MEXICANA
# 4                        TOLUCA                    TOLUCA     MEXICANA
# 5                NICOLAS ROMERO            NICOLAS ROMERO     MEXICANA
# ...                         ...                       ...          ...
# 36261          VILLA DE ALVAREZ          VILLA DE ALVAREZ     MEXICANA
# 36262                     CHILA      CHILAS DE LAS FLORES     MEXICANA
# 36263          VILLA DE ALVAREZ          VILLA DE ALVAREZ     MEXICANA
# 36264  SAN NICOLAS DE LOS GARZA  SAN NICOLAS DE LOS GARZA     MEXICANA
# 36265  SAN NICOLAS DE LOS GARZA  SAN NICOLAS DE LOS GARZA     MEXICANA
#
#       estatura complexion    sexo  edad  \
# 1          1.1    DELGADA   MUJER     4
# 2          1.1    DELGADA  HOMBRE     6
# 3          1.1    DELGADA  HOMBRE    10
# 4          1.1    DELGADA  HOMBRE     4
# 5          1.1    DELGADA  HOMBRE     9
# ...        ...        ...     ...   ...
# 36261      1.7    ROBUSTA   MUJER    27
# 36262     1.77    MEDIANA   MUJER    86
# 36263     1.76    ROBUSTA  HOMBRE    41
# 36264      1.6    DELGADA   MUJER    14
# 36265      1.6    DELGADA   MUJER    14
#
#                                       senas_particulares            etnia  \
# 1                                        NO ESPECIFICADO  NO ESPECIFICADO
# 2      MANCHAS, PARTE SUPERIOR DE PIERNA DERECHA, CIC...  NO ESPECIFICADO
# 3      LUNARES, A LA ALTURA DE LA CINTURAFORMA DE MAN...  NO ESPECIFICADO
# 4                                        NO ESPECIFICADO  NO ESPECIFICADO
# 5                                        NO ESPECIFICADO  NO ESPECIFICADO
# ...                                                  ...              ...
# 36261  EL OJO IZQUIERDO TIENE UN ENFERMEDAD COMO TIC,...  NO ESPECIFICADO
# 36262                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36263  TATUAJE EN EL BRAZO IZQUIERDO CON LA IMAGEN DE...  NO ESPECIFICADO
# 36264                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36265                                    NO ESPECIFICADO  NO ESPECIFICADO
#
#       discapacidad       dependecia_origen
# 1          NINGUNO  FGJ - ESTADO DE MEXICO
# 2          NINGUNO  FGJ - ESTADO DE MEXICO
# 3          NINGUNO  FGJ - ESTADO DE MEXICO
# 4          NINGUNO  FGJ - ESTADO DE MEXICO
# 5          NINGUNO  FGJ - ESTADO DE MEXICO
# ...            ...                     ...
# 36261      NINGUNO            PGJ - COLIMA
# 36262      NINGUNO            FGE - PUEBLA
# 36263      NINGUNO            PGJ - COLIMA
# 36264      NINGUNO        PGJ - NUEVO LEON
# 36265      NINGUNO        PGJ - NUEVO LEON
#
# [36265 rows x 15 columns]

# %%
df_2['edad'].describe()
# Out:
# count    36265.000000
# mean        28.121302
# std         16.777974
# min          0.000000
# 25%         17.000000
# 50%         27.000000
# 75%         38.000000
# max        103.000000
# Name: edad, dtype: float64

# %%
# CONSTRUIMOS NUEVOS DATA FRAMES PARA INTENTAR RESPONDER LAS PREGUNTAS PLANTEADAS
estados= pd.Series(df_2['entidad_ultvz'], name='Estado')
cuenta = df_2.groupby(['entidad_ultvz']).size()
df_freq_estados = pd.DataFrame(df_2.groupby(['entidad_ultvz']).size())
df_freq_estados = df_freq_estados.rename(columns = {0:"Frecuencia"})
  
df_freq_estados
# Out:
#                       Frecuencia
# entidad_ultvz
# AGUASCALIENTES               223
# BAJA CALIFORNIA             1024
# BAJA CALIFORNIA SUR           39
# CAMPECHE                      35
# CHIAPAS                      108
# CHIHUAHUA                   2186
# CIUDAD DE MEXICO             744
# COAHUILA DE ZARAGOZA        1753
# COLIMA                       593
# DURANGO                      420
# ESTADO DE MEXICO            3890
# GUANAJUATO                   615
# GUERRERO                    1482
# HIDALGO                      173
# JALISCO                     3362
# MICHOACAN                   1215
# MORELOS                      241
# NAYARIT                      145
# NO ESPECIFICADO               29
# NUEVO LEON                  2896
# OAXACA                       191
# PUEBLA                      2069
# QUERETARO                    284
# QUINTANA ROO                  61
# SAN LUIS POTOSI               97
# SINALOA                     3027
# SONORA                      2149
# TABASCO                       67
# TAMAULIPAS                  5990
# TLAXCALA                      24
# VERACRUZ                     524
# YUCATAN                       99
# ZACATECAS                    510

# %%
# AGREGAMOS UN IDENTIFICADOR UNICO CON RESPECTO AL INDEX ACTUAL

#  COMO EL DATAFRAME ORIGINAL NO CONTIENE UN IDENTIFICADOR UNICO DIFERENTE AL INDEX, UTILIZAREMOS EL VALOR DEL INDEX PARA IDENTIFICAR A LOS SUJETOS


if set(['id']).issubset(df_2.columns):
   print("ya existe ID")
else:
  df_2.insert(0,"id", df_2.index, allow_duplicates=False)

df_2
# Out:
#           id fecha_ultvz hora_ultvz pais_ultvz     entidad_ultvz  \
# 1          1  2007-02-05   02:00:26     MEXICO  ESTADO DE MEXICO
# 2          2  2009-03-14   08:30:54     MEXICO  ESTADO DE MEXICO
# 3          3  2006-12-23   08:00:28     MEXICO  ESTADO DE MEXICO
# 4          4  2008-01-11   12:00:17     MEXICO  ESTADO DE MEXICO
# 5          5  2012-05-27   12:00:43     MEXICO  ESTADO DE MEXICO
# ...      ...         ...        ...        ...               ...
# 36261  36261  2018-01-08   11:00:00     MEXICO            COLIMA
# 36262  36262  2015-02-02   07:00:00     MEXICO            PUEBLA
# 36263  36263  2017-08-22   04:00:00     MEXICO            COLIMA
# 36264  36264  2018-04-11   02:00:00     MEXICO        NUEVO LEON
# 36265  36265  2018-04-11   02:00:00     MEXICO        NUEVO LEON
#
#                 municipio_ultvz           localidad_ultvz nacionalidad  \
# 1                VALLE DE BRAVO            VALLE DE BRAVO     MEXICANA
# 2                        CHALCO                    CHALCO     MEXICANA
# 3           TLALNEPANTLA DE BAZ       TLALNEPANTLA DE BAZ     MEXICANA
# 4                        TOLUCA                    TOLUCA     MEXICANA
# 5                NICOLAS ROMERO            NICOLAS ROMERO     MEXICANA
# ...                         ...                       ...          ...
# 36261          VILLA DE ALVAREZ          VILLA DE ALVAREZ     MEXICANA
# 36262                     CHILA      CHILAS DE LAS FLORES     MEXICANA
# 36263          VILLA DE ALVAREZ          VILLA DE ALVAREZ     MEXICANA
# 36264  SAN NICOLAS DE LOS GARZA  SAN NICOLAS DE LOS GARZA     MEXICANA
# 36265  SAN NICOLAS DE LOS GARZA  SAN NICOLAS DE LOS GARZA     MEXICANA
#
#       estatura complexion    sexo  edad  \
# 1          1.1    DELGADA   MUJER     4
# 2          1.1    DELGADA  HOMBRE     6
# 3          1.1    DELGADA  HOMBRE    10
# 4          1.1    DELGADA  HOMBRE     4
# 5          1.1    DELGADA  HOMBRE     9
# ...        ...        ...     ...   ...
# 36261      1.7    ROBUSTA   MUJER    27
# 36262     1.77    MEDIANA   MUJER    86
# 36263     1.76    ROBUSTA  HOMBRE    41
# 36264      1.6    DELGADA   MUJER    14
# 36265      1.6    DELGADA   MUJER    14
#
#                                       senas_particulares            etnia  \
# 1                                        NO ESPECIFICADO  NO ESPECIFICADO
# 2      MANCHAS, PARTE SUPERIOR DE PIERNA DERECHA, CIC...  NO ESPECIFICADO
# 3      LUNARES, A LA ALTURA DE LA CINTURAFORMA DE MAN...  NO ESPECIFICADO
# 4                                        NO ESPECIFICADO  NO ESPECIFICADO
# 5                                        NO ESPECIFICADO  NO ESPECIFICADO
# ...                                                  ...              ...
# 36261  EL OJO IZQUIERDO TIENE UN ENFERMEDAD COMO TIC,...  NO ESPECIFICADO
# 36262                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36263  TATUAJE EN EL BRAZO IZQUIERDO CON LA IMAGEN DE...  NO ESPECIFICADO
# 36264                                    NO ESPECIFICADO  NO ESPECIFICADO
# 36265                                    NO ESPECIFICADO  NO ESPECIFICADO
#
#       discapacidad       dependecia_origen
# 1          NINGUNO  FGJ - ESTADO DE MEXICO
# 2          NINGUNO  FGJ - ESTADO DE MEXICO
# 3          NINGUNO  FGJ - ESTADO DE MEXICO
# 4          NINGUNO  FGJ - ESTADO DE MEXICO
# 5          NINGUNO  FGJ - ESTADO DE MEXICO
# ...            ...                     ...
# 36261      NINGUNO            PGJ - COLIMA
# 36262      NINGUNO            FGE - PUEBLA
# 36263      NINGUNO            PGJ - COLIMA
# 36264      NINGUNO        PGJ - NUEVO LEON
# 36265      NINGUNO        PGJ - NUEVO LEON
#
# [36265 rows x 16 columns]

# %%
df_nac= pd.crosstab(index=df_2['nacionalidad'],  columns='recuento', colnames=['nacionalidad'])
print(f'En Méxio estan perdidas personas de {len(df_nac.index)} nacionalidades, dstribuidos de la siguiente manera: \n')
df_nac
#f=df_nac['recuento'].max()
#df3=df_nac.merge(df_nac,left_on=f, right_on= how='left')
# Out:
# En Méxio estan perdidas personas de 26 nacionalidades, dstribuidos de la siguiente manera:
# nacionalidad     recuento
# nacionalidad
# ALEMANA                 1
# ARGENTINA               1
# BRASILEÑA               1
# CANADIENSE              3
# CHINA                   1
# COLOMBIANA              9
# COSTARICENSE            1
# CUBANA                  3
# DOMINICANA              1
# ERITREA                 1
# ESPAÑOLA                3
# ESTADOUNIDENSE        124
# FRANCESA                1
# GUATEMALTECO           12
# HAITIANA                2
# HOLANDESA               1
# HONDUREÑA              24
# ITALIANA                3
# MEXICANA            34016
# NICARAGUENSE            1
# NO ESPECIFICADO      2040
# PANAMEÑA                1
# PARAGUAYA               1
# PERUANA                 2
# SALVADOREÑA             8
# VENEZOLANA              4
